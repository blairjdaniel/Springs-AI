# %%
# Add the path to the 'my_llm' module
import sys
sys.path.append('../src')
from my_prompt_engineering.few_shot import generate_few_shot_prompt


from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
# from my_prompt_engineering.few_shot import generate_text

# %%
# # Load model directly
# from transformers import AutoTokenizer, AutoModelForCausalLM

# tokenizer = AutoTokenizer.from_pretrained("google/gemma-7b")
# model = AutoModelForCausalLM.from_pretrained("google/gemma-7b")

# %%
# # Save locally
# local_dir = "/Users/blairjdaniel/AI-Assistant-Springs/models/gemma-7"

# model.save_pretrained(local_dir)
# tokenizer.save_pretrained(local_dir)

# print("Model and processor saved locally at:", local_dir)

# %%
# # Define the sample prompt
# sample_prompt = "Hi, Welcome, do you mind if I call you Kelsey?"

# # Tokenize the input and generate output
# input_ids = tokenizer.encode(sample_prompt, return_tensors="pt")
# outputs = model.generate(input_ids, max_length=100)

# # Decode and print the generated output
# generated_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
# print(generated_output)

# %%
# from transformers import pipeline

# def test_distilbert_classification():
#     # Initialize the text classification pipeline with DistilBERT.
#     classifier = pipeline("text-classification", model="/Users/blairjdaniel/AI-Assistant-Springs/models/distilbert-email-classifier", tokenizer="/Users/blairjdaniel/AI-Assistant-Springs/models/distilbert-email-classifier")
    
#     # Sample texts to classify; you can adjust these to your use case.
#     test_subjects = [
#         "Springs RV Resort Contact Us",
#         "Springs RV Resort Join the waitlist",
#         "RV Lot Phase 3 Price List - Springs RV Resort",
#         "I have a question about your services",
#         "RV Lot Sales"
#     ]
    
#     # Process each test subject and print the results.
#     for subject in test_subjects:
#         result = classifier(subject)
#         print("Input:", subject)
#         print("Output:", result)
#         print("-" * 60)

# if __name__ == "__main__":
#     test_distilbert_classification()

# %%
model = AutoModelForCausalLM.from_pretrained('/Users/blairjdaniel/AI-Assistant-Springs/models/gpt')
tokenizer = AutoTokenizer.from_pretrained('/Users/blairjdaniel/AI-Assistant-Springs/models/gpt')

# Example usage
email_text = "Hi, I’d like to book a tour for Saturday at 11am. Is that possible?"
sender_name = "Elizabeth"

# Generate the few-shot prompt
prompt = generate_few_shot_prompt(email_text, sender_name)

# Tokenize the input and generate output
input_ids = tokenizer.encode(prompt, return_tensors="pt")
outputs = model.generate(input_ids, max_length=1000)

# Decode and print the generated output
generated_response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(generated_response)
# Out:
# 2025-04-08 09:19:08.235196: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Example 1:
# Email:
# Hi, I’d like to know more about your RV lots. Are there any available for purchase?
#
# Response:
# Hi Elizabeth,
#
# ...

# %%
# from transformers import AutoModelForCausalLM, AutoTokenizer

# model_name = "Qwen/QwQ-32B"

# model = AutoModelForCausalLM.from_pretrained(
#     model_name,
#     torch_dtype="auto",
#     device_map="auto"
# )
# tokenizer = AutoTokenizer.from_pretrained(model_name)

# prompt = "How many r's are in the word \"strawberry\""
# messages = [
#     {"role": "user", "content": prompt}
# ]
# text = tokenizer.apply_chat_template(
#     messages,
#     tokenize=False,
#     add_generation_prompt=True
# )

# model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# generated_ids = model.generate(
#     **model_inputs,
#     max_new_tokens=32768
# )
# generated_ids = [
#     output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
# ]

# response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
# print(response)

# %%
# from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# # Define the model directory or Hugging Face model name
# model_name = "google/flan-t5-large"
# output_dir = "/Users/blairjdaniel/AI-Assistant-Springs/models/flan_large"

# # Load the model and tokenizer
# model = AutoModelForSeq2SeqLM.from_pretrained(model_name, cache_dir=output_dir)
# tokenizer = AutoTokenizer.from_pretrained(model_name, cache_dir=output_dir)

# # Define the sample prompt
# sample_prompt = "Hi, welcome! I have been training you on data from my company, I'd like to call you Kelsey, is that ok?"

# # Tokenize the input and generate output
# input_ids = tokenizer.encode(sample_prompt, return_tensors="pt")
# outputs = model.generate(input_ids, max_length=100)

# # Decode and print the generated output
# generated_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
# print(generated_output)

# %%
# # Define the sample prompt
# sample_prompt = "Can you read an email and send a response?"

# # Tokenize the input and generate output
# input_ids = tokenizer.encode(sample_prompt, return_tensors="pt")
# outputs = model.generate(input_ids, max_length=100)

# # Decode and print the generated output
# generated_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
# print(generated_output)

# %%
# # Provided email sample (line 45 from email_contact.csv)
# email_text = """I'd like to book a tour for Saturday at 2pm.

# Warm Regards
# Elizabeth

# > On Wed, Oct 30, 2024 at 12:14 PM Springs RV Resort <sales@springsrv.com> wrote:
# > >> From: Elizabeth <lizchang@telus.net>
# > >> City: Vancouver
# > >> Phone: 7788366060
# > >> When would you like to come for a tour?:
# > >> November 6
# > >> What are you interested in?:
# > >> purchase of a lot
# > >> Anything you'd like to ask us?:
# > >> any restrictions on RV's
# > >> Page: https://springsrv.com/phase-3-lots-for-sale/"""

# # Define baseline responses you'd like the model to consider in its reply
# baseline_responses = """Baseline Responses:
# Hi Elizabeth,

#       Thanks so much for reaching out! My name is Kelsey, and I’m the Sales Assistant here at Springs RV Resort.
      
#       I’d be happy to set you up with our Sales Manager, Jamie Smith, for a personal resort tour so you can get a feel for what makes the Springs so special. You’re welcome to reply with a day and time that works best for you, or you can book directly using our online calendar (BOOK HERE) or call 778-871-3160.
      
#       As you may know, our resort offers daily rentals, seasonal rentals, and RV lot ownership. If you’re exploring ownership, our brand-new Phase 3 lots range from $269,000 to over $300,000. We also have a selection of resale lots available; you can browse listings with photos and pricing (see details here).
      
#       If you have any questions or would like to chat before your visit, I’m always here to help!
      
#       Warmly,
#       Kelsey
#       Sales Assistant
#       sales@springsrv.com
      
#       Please note: Our Resort is recreational use only and does not allow full-time living.
# Reply:"""

# # Combine the email and baseline responses into one prompt
# prompt = email_text + "\n\n" + baseline_responses

# # Specify where your fine-tuned model is saved
# output_dir = "/Users/blairjdaniel/AI-Assistant-Springs/models/flan_large"
# # Tokenize the input and generate output
# input_ids = tokenizer.encode(prompt, return_tensors="pt")
# outputs = model.generate(input_ids, max_length=500)

# # Decode and print the generated output
# generated_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
# print(generated_output)

# %%
# sample_prompt = "Can you give me a new Brand Book entry on training new management?"
# output_dir = "/Users/blairjdaniel/AI-Assistant-Springs/models/gpt2_finetuned_four"
# generated_output = generate_text(sample_prompt, output_dir, max_length=100)
# print(generated_output)

# %%
# sample_prompt = "What is the capital of France?"
# output_dir = "/Users/blairjdaniel/AI-Assistant-Springs/models/gpt2_finetuned_four?"
# print(generated_output)

# %%
# output_dir = "/Users/blairjdaniel/AI-Assistant-Springs/models/gpt2_finetuned_four"
# sample_prompt = """
# Q: What is the capital of Germany?
# A: The capital of Germany is Berlin.

# Q: What is the capital of France?
# A:"""
# generated_output = generate_text(sample_prompt, output_dir, max_length=50)
# print(generated_output)

# %%
# output_dir = "/Users/blairjdaniel/AI-Assistant-Springs/models/gpt2_finetuned_four"
# sample_prompt = "Answer the following question concisely: What is the capital of France?"
# generated_output = generate_text(sample_prompt, output_dir, max_length=50)
# print(generated_output)
